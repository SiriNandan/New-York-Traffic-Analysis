# %% [markdown]
# # DATA GATHERING

# %% [markdown]
# THE TRAIN DATASET : C:\\Users\\Lenovo\\Downloads\\train.csv

# %% [markdown]
# THE TEST DATASET : C:\\Users\\Lenovo\\Downloads\\test.csv

# %% [markdown]
# IMPORT PANDAS LIBRARY

# %%
import pandas as pd # importing the LIBRARY 
import datetime as dt
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# # Import Data

# %% [markdown]
# Import the data from a csv file.

# %%
taxi=pd.read_csv("C:\\Users\\Lenovo\\Downloads\\train.csv")

# %%
taxi # dataset stored in this variable
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# Getting only first 5 rows using head() function

# %%
taxi.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# ...

# %% [markdown]
# Getting last 5 rows using tail() function

# %%
taxi.tail()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1458639                4        -73.982201        40.745522
# 1458640                1        -74.000946        40.747379
# 1458641                1        -73.959129        40.768799
# 1458642                1        -73.982079        40.749062
# 1458643                1        -73.979538        40.781750
#
#          dropoff_longitude  dropoff_latitude store_and_fwd_flag  trip_duration
# 1458639         -73.994911         40.740170                  N            778
# ...

# %% [markdown]
# # Explore Data

# %%
taxi.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %% [markdown]
# 1.First and most important thing checking for null values using isna().sum()

# %% [markdown]
# isna() : Checks the null values

# %% [markdown]
# sum() : Sum function prints the total number of null values

# %%
taxi.isna().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %% [markdown]
# There are no null values

# %% [markdown]
# Explore the Data Analysis

# %% [markdown]
# Getting the information using info() function.

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %% [markdown]
# Getting the number of columns and rows using shape property

# %%
taxi.shape
# Out:
# (1458644, 11)

# %% [markdown]
# number_of_rows = 1458644 , number_of_columns = 11

# %% [markdown]
# # Features

# %% [markdown]
# 1. id column has unique values which means its no use to take id in model training
# 2. Columns such as pickup_datetime,dropoff_datetime has object dtype and the values are
#    datetype which may not able to evaluate by model which can affect in accuracy.
# 3. passenger_count, pickup_longitude, pickup_latitude and dropoff_longitude, dropoff_latitude are the
#    columns which are dependent on each other.
# 4. Other than this store_and_fwd_flag is just a service info column.
# 5. trip_duration is our target.

# %%
# #2.Convert timestamp to datetime format to fetch the other details as listed below
taxi['pickup_datetime'] = pd.to_datetime(taxi['pickup_datetime'])
taxi['dropoff_datetime'] = pd.to_datetime(taxi['dropoff_datetime'])
#Calculate and assign new columns to the dataframe such as weekday,
#month and pickup_hour which will help us to gain more insights from 
# the data.
taxi['weekday'] = taxi.pickup_datetime.dt.weekday
taxi['month'] = taxi.pickup_datetime.dt.month
taxi['weekday_num'] = taxi.pickup_datetime.dt.weekday
taxi['pickup_hour'] = taxi.pickup_datetime.dt.hour

# %% [markdown]
# 6. Therefore pickup_datetime is been converted into weekday, month, weekday_num, pickup_hour

# %%
taxi
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0        id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1        id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2        id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3        id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4        id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
# ...            ...        ...                 ...                 ...
# 1458639  id2376096          2 2016-04-08 13:31:04 2016-04-08 13:44:02
# 1458640  id1049543          1 2016-01-10 07:35:15 2016-01-10 07:46:10
# 1458641  id2304944          2 2016-04-22 06:57:41 2016-04-22 07:10:25
# 1458642  id2714485          1 2016-01-05 15:56:26 2016-01-05 16:02:39
# 1458643  id1209952          1 2016-04-05 14:44:25 2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 0                      1        -73.982155        40.767937
# ...

# %% [markdown]
# # Pick Up Points v/s Dropoff Points

# %% [markdown]
# Here we take a look at the spread of Pickup co-ordinates and Drop-off co-ordinates across city

# %%
city_long_border = (-74.03, -73.75)
city_lat_border = (40.63, 40.85)
fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True,figsize = (12,5))
ax[0].scatter(taxi['pickup_longitude'].values, taxi['pickup_latitude'].values,
color='blue', s=1, label='train', alpha=0.1)
ax[1].scatter(taxi['dropoff_longitude'].values, taxi['dropoff_latitude'].values,
color='green', s=1, label='train', alpha=0.1)
ax[1].set_title('Drop-off Co-ordinates')
ax[0].set_title('Pick-up Co-ordinates')
ax[0].set_ylabel('Latitude')
ax[0].set_xlabel('Longitude')
ax[1].set_ylabel('Latitude')
ax[1].set_xlabel('Longitude')
plt.ylim(city_lat_border)
plt.xlim(city_long_border)
plt.show()

# %% [markdown]
# x_feature variable will be assigned all the columns [vendor_id, passenger_count, pickup_longitude,	pickup_latitude, dropoff_longitude, dropoff_latitude, weekday, month, weekday_num, pickup_hour]

# %% [markdown]
# y_target variable will be assigned by only one dependent columns[trip_duration]

# %%
# define x_feature is the independent_features and y_target is the dependent_feature 
x_feature = taxi.iloc[:, [1,4,6,8,11,12,13,14]].values
y_target = taxi.iloc[:,10].values
x_train, x_test, y_train, y_test = train_test_split(x, y, 
test_size=0.2,random_state = 7294)

# %% [markdown]
# shape gives the number of columns = 5 and rows = 1458644

# %%
x_feature.shape
# Out:
# (1458644, 8)

# %% [markdown]
# shape gives the number of rows = 1458644

# %%
y_target.shape
# Out:
# (1458644,)

# %% [markdown]
# # Splitting the Dataset into Train and Test

# %% [markdown]
# 1. Using sklearn library we are importing train_test_selection function from model_selection module
# 2. train_test_split will split the dataset into (70% to train_set) and (30% to test_set)
# 3. And we are assigning to 4 variables x_train,x_test,y_train,y_test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_feature,y_target,test_size = 0.3,random_state=2529)

# %%
x_train # As we can observe the rows of the dataset is splitted into 70%
# Out:
# array([[ 1.        ,  1.        , 40.77898026, ...,  6.        ,
#          1.        , 11.        ],
#        [ 1.        ,  2.        , 40.7608223 , ...,  6.        ,
#          2.        ,  0.        ],
#        [ 1.        ,  1.        , 40.72604752, ...,  5.        ,
#          1.        , 21.        ],
#        ...,
#        [ 2.        ,  3.        , 40.7074585 , ...,  5.        ,
#          1.        , 10.        ],
#        [ 2.        ,  5.        , 40.76451111, ...,  3.        ,
#          4.        , 18.        ],
#        [ 1.        ,  1.        , 40.64665222, ...,  1.        ,
#          5.        , 13.        ]])

# %%
y_train # As we can observe the rows of the dataset is splitted into 70%
# Out:
# array([1931,  177,  770, ...,  257,  782, 1973], dtype=int64)

# %%
x_test # As we can observe the rows of the dataset is splitted into 30%
# Out:
# array([[ 1.        ,  1.        , 40.74523926, ...,  5.        ,
#          1.        , 19.        ],
#        [ 2.        ,  1.        , 40.74290085, ...,  2.        ,
#          2.        , 16.        ],
#        [ 2.        ,  1.        , 40.77106857, ...,  6.        ,
#          0.        , 17.        ],
#        ...,
#        [ 1.        ,  1.        , 40.74497986, ...,  1.        ,
#          4.        , 19.        ],
#        [ 1.        ,  1.        , 40.71489334, ...,  2.        ,
#          6.        ,  0.        ],
#        [ 1.        ,  2.        , 40.75430298, ...,  2.        ,
#          4.        , 22.        ]])

# %%
y_test # As we can observe the rows of the dataset is splitted into 30%
# Out:
# array([1357,  268,  116, ...,  892, 1651,  931], dtype=int64)

# %% [markdown]
# # Multiple Linear Regression
#
#     It is used to explain the relationship between one continuous dependent variable and two or
#     more independent variables.

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression() # y=mx+c
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_  # c = intercept
# Out:
# 224706.49937506183

# %%
model.coef_ # m = slope
# Out:
# array([ 2.04552150e+02,  1.16896216e+01, -3.95032153e+03, -1.55078924e+03,
#        -2.65864683e+00,  2.21163921e+01, -2.65864683e+00,  2.44169807e+00])

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([ 872.0237128 , 1073.07863249, 1022.91448274, ...,  787.46685453,
#         835.41613781,  850.40596525])

# %%
predictions = pd.DataFrame({'Actual': y_test, 'Predicted': 
y_predict.flatten()})

# %%
predictions
# Out:
#         Actual    Predicted
# 0         1357   872.023713
# 1          268  1073.078632
# 2          116  1022.914483
# 3         1073  1127.462460
# 4          485   923.022073
# ...        ...          ...
# 437589     491   659.227749
# 437590     313  1000.395052
# 437591     892   787.466855
# 437592    1651   835.416138
# 437593     931   850.405965
#
# [437594 rows x 2 columns]

# %% [markdown]
# # Accuracy score

# %% [markdown]
# From the module metrics we have imported a function called mean_absolute_percentage_error()

# %% [markdown]
# mean_absolute_percentage_error : It gives the error percentage between y_test and y_predict

# %%
mean_absolute_percentage_error(y_test,y_predict)
# Out:
# 1.6056474851168727

# %% [markdown]
# The Accuracy rate of the taxi_duration is 100% - 16% = 84%(accuracy_score) which is good but it is quite low for a regression model
